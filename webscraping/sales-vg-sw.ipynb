# %% [markdown]
# # Web scraping the weekly Japanese software videogame sales
#
# First I want to obtain a dataframe for the top 30 videogame sales using only one week, in order to test the code previous to the data minning.
#
# In the block below I am going to import the libraries that I'm using:

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
import time
import datetime
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# I'm going to use a week where there is at least one new release, as the row structure is different, as we will see.
#
# Below, using `requests` and `BeautifulSoup` I will obtain all the text from the first post.
#
# I will print it in screen to see the structure.

# %%
url_tab = 'https://www.resetera.com/threads/media-create-sales-week-46-2018-nov-12-nov-18.82357/'

# %%
def obtain_post(url):
    # With request and with the BeautifulSoup class we obtain the code of the page of the URL.
    post = requests.get(url)
    soup = BeautifulSoup(post.text)
    # Divide the code in posts
    post_data=soup.findAll("div", {"class": "bbWrapper"})
    # Obtain the text inside the first post
    return post_data[0].text


tab_top30=obtain_post(url_tab)
print(tab_top30)
# Out:
#
# Media Create Sales: Week 46, 2018 (Nov 12 - Nov 18)
#
# 01./00.  [NSW] Pokemon: Let's Go, Pikachu! / Let's Go, Eevee! # <RPG> (Pokemon Co.) {2018.11.16} (¥5.980) - 661.240 / NEW
# 02./00.  [PS4] Fallout 76 # <RPG> (Bethesda Softworks) {2018.11.15} (¥7.980) - 73.489 / NEW
# 03./03. [NSW] Super Mario Party <ETC> (Nintendo) {2018.10.05} (¥5.980) - 20.942 / 345.627 (-10%)
# 04./02. [PS4] Call of Duty: Black Ops IIII <ACT> (Sony Interactive Entertainment) {2018.10.12} (¥7.900) - 17.159 / 460.890 (-33%)
# 05./00.  [PS4] Hitman 2 <ADV> (Warner Entertainment Japan) {2018.11.15} (¥7.800) - 10.162 / NEW
# 06./01. [3DS] Luigi's Mansion <ACT> (Nintendo) {2018.11.08} (¥4.980) - 9.320 / 36.689 (-66%)
# 07./05. [NSW] Mario Kart 8 Deluxe <RCE> (Nintendo) {2017.04.28} (¥5.980) - 9.319 / 1.836.063 (+10%)
# 08./04. [PS4] Red Dead Redemption II # <ACT> (Take-Two Interactive Japan) {2018.10.26} (¥8.800) - 8.120 / 192.181 (-52%)
# 09./07. [NSW] Splatoon 2 # <ACT> (Nintendo) {2017.07.21} (¥5.980) - 7.992 / 2.698.886 (+18%)
# 10./06. [NSW] Minecraft <ADV> (Microsoft Game Studios) {2018.06.21} (¥3.600) - 7.449 / 365.347 (-1%)
# 11./08. [NSW] The Legend of Zelda: Breath of the Wild # <ADV> (Nintendo) {2017.03.03} (¥6.980) - 6.215 / 1.159.398 (+9%)
# 12./00.  [PS4] Yuuna and the Haunted Hot Springs: Steam Dungeon # <RPG> (FuRyu) {2018.11.15} (¥7.980) - 5.025 / NEW
# 13./10. [NSW] Super Mario Odyssey # <ACT> (Nintendo) {2017.10.27} (¥5.980) - 3.990 / 1.845.682 (+6%)
# 14./12. [3DS] Pokemon Ultra Sun / Ultra Moon <RPG> (Pokemon Co.) {2017.11.17} (¥4.980) - 3.493 / 1.760.304 (+4%)
# 15./11. [PS4] Marvel's Spider-Man # <ADV> (Sony Interactive Entertainment) {2018.09.07} (¥6.900) - 3.134 / 305.030 (-17%)
# 16./14. [NSW] Kirby Star Allies <ACT> (Nintendo) {2018.03.16} (¥5.980) - 2.958 / 642.205 (+0%)
# 17./00.  [NSW] RPG Maker MV Trinity <ETC> (Kadokawa Games) {2018.11.15} (¥7.800) - 2.641 / NEW
# 18./16. [NSW] Taiko no Tatsujin: Drum 'n' Fun! <ACT> (Bandai Namco Games) {2018.07.19} (¥6.100) - 2.181 / 225.417 (-12%)
# 19./00.  [PS4] RPG Maker MV Trinity <ETC> (Kadokawa Games) {2018.11.15} (¥7.800) - 2.090 / NEW
# 20./00.  [PSV] Shiro to Kuro no Alice: Twilight Line # <ADV> (Idea Factory) {2018.11.15} (¥6.300) - 2.087 / NEW
# 21./21. [NSW] Mario Tennis Aces <SPT> (Nintendo) {2018.06.22} (¥5.980)
# 22./15. [PS4] Assassin's Creed: Odyssey # <RPG> (Ubisoft) {2018.10.05} (¥8.400)
# 23./22. [3DS] Animal Crossing: New Leaf - Welcome amiibo # <ETC> (Nintendo) {2016.11.23} (¥2.700)
# 24./23. [PS4] Winning Eleven 2019 <SPT> (Konami) {2018.08.30} (¥7.600)
# 25./17. [NSW] Cats Together <ETC> (Bandai Namco Games) {2018.11.01} (¥5.700)
# 26./19. [PS4] Kingdom Hearts HD I.5 + II.5 ReMIX <Kingdom Hearts HD I.5 ReMIX <Kingdom Hearts \ Kingdom Hearts Re:Chain of Memories> \ Kingdom Hearts HD II.5 ReMIX <Kingdom Hearts II \ Kingdom Hearts II: Final Mix+ \ Kingdom Hearts: Birth by Sleep>> <RPG> (Square Enix) {2017.03.09} (¥6.800)
# 27./25. [NSW] Captain Toad: Treasure Tracker <ADV> (Nintendo) {2018.07.13} (¥3.980)
# 28./30. [NSW] FIFA 19 # <SPT> (Electronic Arts) {2018.09.28} (¥5.800)
# 29./26. [NSW] Nintendo Labo Toy-Con 03: Drive Kit <EDU> (Nintendo) {2018.09.14} (¥6.980)
# 30./18. [PS4] Warriors Orochi 4 # <ACT> (Koei Tecmo) {2018.09.27} (¥7.800)
# 31./27. [NSW] Dragon Ball FighterZ <FTG> (Bandai Namco Games) {2018.09.27} (¥6.800)
# 32./24. [PS4] The Legend of Heroes: Trails of Cold Steel IV - The End of Saga # <RPG> (Nihon Falcom) {2018.09.27} (¥7.800)
# 33./31. [3DS] WarioWare Gold <ETC> (Nintendo) {2018.08.02} (¥4.980)
# 34./35. [NSW] Pro Baseball Famista Evolution <SPT> (Bandai Namco Games) {2018.08.02} (¥6.100)
# 35./28. [PS4] FIFA 19 # <SPT> (Electronic Arts) {2018.09.28} (¥7.800)
# 36./00.  [NSW] Legendary Fishing <SPT> (Ubisoft) {2018.11.15} (¥4.800)
# 37./09. [PS4] Tetris Effect <PZL> (Sony Interactive Entertainment) {2018.11.09} (¥4.167)
# 38./29. [NSW] Dark Souls Remastered <Dark Souls \ Dark Souls: Artorias of the Abyss> <RPG> (From Software) {2018.10.18} (¥4.800)
# 39./38. [3DS] Mario Kart 7 # <RCE> (Nintendo) {2011.12.01} (¥4.571)
# 40./00.  [NSW] Monster Hunter Generations Ultimate [Best Price] <ACT> (Capcom) {2018.11.15} (¥3.990)
# 41./39. [NSW] Sumikko Gurashi: Atsumare! Sumikko Town <ETC> (Nippon Columbia) {2018.10.04} (¥5.800)
# 42./20. [PS4] Soul Calibur VI <FTG> (Bandai Namco Games) {2018.10.18} (¥7.600)
# 43./37. [3DS] Captain Toad: Treasure Tracker <ADV> (Nintendo) {2018.07.13} (¥3.980)
# 44./47. [NSW] Pokken Tournament DX <FTG> (Pokemon Co.) {2017.09.22} (¥5.980)
# 45./36. [PS4] Gran Turismo Sport # <RCE> (Sony Interactive Entertainment) {2017.10.19} (¥6.900)
# 46./00. [PS4] Street Fighter 30th Anniversary Collection <Street Fighter \ Street Fighter II \ Street Fighter II: Champion Edition \ Street Fighter II: Hyper Fighting \ Super Street Fighter II \ Super Street Fighter II Turbo \ Street Fighter Alpha \ Street Fighter Alpha 2 \ Street Fighter Alpha 3 \ Street Fighter III \ Street Fighter III: 2nd Impact \ Street Fighter III: 3rd Strike> # <FTG> (Capcom) {2018.10.25} (¥4.990)
# 47./33. [NSW] Nintendo Labo Toy-Con 01: Variety Kit <EDU> (Nintendo) {2018.04.20} (¥6.980)
# 48./40. [NSW] Warriors Orochi 4 # <ACT> (Koei Tecmo) {2018.09.27} (¥7.800)
# 49./49. [3DS] Mario Party: The Top 100 <ETC> (Nintendo) {2017.12.28} (¥4.980)
# 50./13. [PS4] Deracine |PlayStation VR| # <ADV> (Sony Interactive Entertainment) {2018.11.08} (¥3.000)
#
#  Top 50
#
# NSW - 24
# PS4 - 18
# 3DS - 7
# PSV - 1
#
#  SOFTWARE
#
#
# Code:
#
#
# +-------+------------+------------+------------+------------+------------+
# |System |  This Week |  Last Week |  Last Year |     YTD    |  Last YTD  |
# +-------+------------+------------+------------+------------+------------+
# |  ALL  |    959.000 |    259.000 |  1.345.000 | 21.524.000 | 26.051.000 |
# +-------+------------+------------+------------+------------+------------+
#
# HARDWARE
#
#
# Code:
#
#
# +-------+------------+------------+------------+------------+------------+-------------+
# |System |  This Week |  Last Week |  Last Year |     YTD    |  Last YTD  |     LTD     |
# +-------+------------+------------+------------+------------+------------+-------------+
# |  NSW  |    200.850 |     54.235 |     86.999 |  2.289.338 |  2.252.328 |   5.601.957 |
# | PS4 # |     17.789 |     16.081 |     26.302 |  1.376.944 |  1.465.880 |   7.269.347 |
# | 3DS # |      6.599 |      6.218 |     43.480 |    440.648 |  1.372.373 |  24.263.427 |
# | PSV # |      1.877 |      1.869 |      3.090 |    161.598 |    293.179 |   5.949.478 |
# | XB1 # |        164 |        406 |        247 |     13.345 |      8.071 |     101.781 |
# +-------+------------+------------+------------+------------+------------+-------------+
# |  ALL  |    227.279 |     78.809 |    160.207 |  4.281.873 |  5.427.250 |  43.185.990 |
# +-------+------------+------------+------------+------------+------------+-------------+
# | XB1 X |        119 |        360 |        143 |      8.953 |      1.487 |      11.127 |
# |  XB1  |         45 |         46 |        104 |      4.392 |      6.584 |      90.654 |
# |PS4 Pro|      8.867 |      7.927 |      8.176 |    382.143 |    302.708 |     922.449 |
# |  PS4  |      8.922 |      8.154 |     18.126 |    994.801 |  1.163.172 |   6.346.898 |
# |  PSV  |      1.877 |      1.869 |      3.090 |    161.598 |    293.179 |   5.764.027 |
# |n-2DSLL|      4.189 |      4.243 |     29.013 |    266.821 |    390.840 |     823.179 |
# |  2DS  |        622 |        294 |      3.113 |     31.326 |    181.821 |     525.549 |
# |n-3DSLL|      1.788 |      1.681 |     11.074 |    142.501 |    746.273 |   4.815.375 |
# +-------+------------+------------+------------+------------+------------+-------------+
#
#
#  Famitsu Sales: Week 46, 2018 (Nov 12 - Nov 18)
#
# 01./00.  [NSW] Pokemon: Let's Go, Pikachu! / Let's Go, Eevee! # <RPG> (Pokemon Co.) {2018.11.16} (¥5.980) - 664.198 / NEW <40-60%>
# 02./00.  [PS4] Fallout 76 # <RPG> (Bethesda Softworks) {2018.11.15} (¥7.980) - 60.222 / NEW <60-80%>
# 03./02. [NSW] Super Mario Party <ETC> (Nintendo) {2018.10.05} (¥5.980) - 17.486 / 326.510 <80-100%> (-15%)
# 04./03. [PS4] Call of Duty: Black Ops IIII <ACT> (Sony Interactive Entertainment) {2018.10.12} (¥7.900) - 13.868 / 442.995 <80-100%> (-32%)
# 05./01. [3DS] Luigi's Mansion <ACT> (Nintendo) {2018.11.08} (¥4.980) - 10.716 / 40.121 <40-60%> (-64%)
# 06./00.  [PS4] Hitman 2 <ADV> (Warner Entertainment Japan) {2018.11.15} (¥7.800) - 10.688 / NEW <20-40%>
# 07./05. [NSW] Mario Kart 8 Deluxe <RCE> (Nintendo) {2017.04.28} (¥5.980) - 9.948 / 1.849.467 <80-100%> (+14%)
# 08./04. [PS4] Red Dead Redemption II # <ACT> (Take-Two Interactive Japan) {2018.10.26} (¥8.800) - 7.642 / 189.465 <80-100%> (-48%)
# 09./06. [NSW] Minecraft <ADV> (Microsoft Game Studios) {2018.06.21} (¥3.600) - 7.504 / 366.272 <80-100%> (-2%)
# 10./07. [NSW] Splatoon 2 # <ACT> (Nintendo) {2017.07.21} (¥5.980) - 7.482 / 2.736.533 <80-100%> (+11%)
# 11./08. [NSW] The Legend of Zelda: Breath of the Wild # <ADV> (Nintendo) {2017.03.03} (¥6.980) - 5.463 / 1.121.636 <80-100%> (+12%)
# 12./00.  [PS4] Yuuna and the Haunted Hot Springs: Steam Dungeon # <RPG> (FuRyu) {2018.11.15} (¥7.980) - 5.325 / NEW <40-60%>
# 13./09. [3DS] Pokemon Ultra Sun / Ultra Moon # <RPG> (Pokemon Co.) {2017.11.17} (¥4.980) - 4.049 / 2.395.774 <80-100%> (+1%)
# 14./10. [NSW] Super Mario Odyssey # <ACT> (Nintendo) {2017.10.27} (¥5.980) - 3.630 / 1.836.141 <80-100%> (-6%)
# 15./00.  [PSV] Shiro to Kuro no Alice: Twilight Line # <ADV> (Idea Factory) {2018.11.15} (¥6.300) - 3.068 / NEW <40-60%>
# 16./00.  [NSW] RPG Maker MV Trinity <ETC> (Kadokawa Games) {2018.11.15} (¥7.800) - 3.015 / NEW <20-40%>
# 17./11. [PS4] Marvel's Spider-Man # <ADV> (Sony Interactive Entertainment) {2018.09.07} (¥6.900) - 2.849 / 294.847 <80-100%> (-13%)
# 18./00.  [PS4] RPG Maker MV Trinity <ETC> (Kadokawa Games) {2018.11.15} (¥7.800) - 2.243 / NEW <20-40%>
# 19./12. [NSW] Taiko no Tatsujin: Drum 'n' Fun! <ACT> (Bandai Namco Games) {2018.07.19} (¥6.100) - 2.188 / 224.930 <80-100%> (-5%)
# 20./13. [NSW] Kirby Star Allies <ACT> (Nintendo) {2018.03.16} (¥5.980) - 2.049 / 619.949 <80-100%> (-4%)
# 21./17. [PS4] Winning Eleven 2019 <SPT> (Konami) {2018.08.30} (¥7.600) - 1.841 / 137.378 <80-100%> (+3%)
# 22./16. [PS4] Kingdom Hearts HD I.5 + II.5 ReMIX <Kingdom Hearts HD I.5 ReMIX <Kingdom Hearts \ Kingdom Hearts Re:Chain of Memories> \ Kingdom Hearts HD II.5 ReMIX <Kingdom Hearts II \ Kingdom Hearts II: Final Mix+ \ Kingdom Hearts: Birth by Sleep>> <RPG> (Square Enix) {2017.03.09} (¥6.800) - 1.728 / 215.144 <80-100%> (-12%)
# 23./23. [NSW] Mario Tennis Aces <SPT> (Nintendo) {2018.06.22} (¥5.980) - 1.649 / 351.946 <80-100%> (+9%)
# 24./22. [NSW] FIFA 19 # <SPT> (Electronic Arts) {2018.09.28} (¥5.800) - 1.524 / 36.375 <60-80%> (-6%)
# 25./20. [PS4] FIFA 19 # <SPT> (Electronic Arts) {2018.09.28} (¥7.800) - 1.385 / 93.924 <80-100%> (-19%)
# 26./25. [NSW] Dragon Ball FighterZ <FTG> (Bandai Namco Games) {2018.09.27} (¥6.800) - 1.254 / 44.146 <60-80%> (-13%)
# 27./27. [3DS] Animal Crossing: New Leaf - Welcome amiibo # <ETC> (Nintendo) {2016.11.23} (¥2.700) - 1.239 / 407.238 <80-100%> (-3%)
# 28./19. [PS4] Tetris Effect <PZL> (Sony Interactive Entertainment) {2018.11.09} (¥4.167) - 1.238 / 3.016 <20-40%> (-30%)
# 29./14. [PS4] Assassin's Creed: Odyssey # <RPG> (Ubisoft) {2018.10.05} (¥8.400) - 1.237 / 83.996 <80-100%> (-39%)
# 30./21. [NSW] Cats Together <ETC> (Bandai Namco Games) {2018.11.01} (¥5.700) - 1.202 / 5.979 <20-40%> (-26%)
#
#  Top 30
#
# NSW - 14
# PS4 - 12
# 3DS - 3
# PSV - 1
#
# HARDWARE
#
#
# Code:
#
#
# +-------+------------+------------+------------+------------+------------+-------------+
# |System |  This Week |  Last Week |  Last Year |     YTD    |  Last YTD  |     LTD     |
# +-------+------------+------------+------------+------------+------------+-------------+
# |  NSW  |    180.585 |     53.385 |     90.303 |  2.210.304 |  2.280.094 |   5.617.462 |
# | PS4 # |     15.890 |     16.216 |     31.862 |  1.345.825 |  1.594.776 |   7.202.688 |
# | 3DS # |      6.056 |      6.041 |     40.582 |    481.959 |  1.538.817 |  24.220.503 |
# | PSV # |      1.818 |      1.668 |      2.716 |    167.213 |    347.156 |   5.810.839 |
# | XB1 # |        202 |        473 |        161 |     12.947 |      8.371 |     100.539 |
# +-------+------------+------------+------------+------------+------------+-------------+
# |  ALL  |    204.551 |     77.783 |    165.698 |  4.220.252 |  5.806.710 |  46.255.590 |
# +-------+------------+------------+------------+------------+------------+-------------+
# | XB1 X |        169 |        416 |         94 |      9.164 |      1.733 |      11.467 |
# | XB1 S |         33 |         57 |         67 |      3.783 |      1.856 |      17.070 |
# |PS4 Pro|      7.581 |      7.933 |      8.397 |    364.627 |    296.668 |     879.571 |
# |  PS4  |      8.309 |      8.283 |     23.465 |    981.198 |  1.298.108 |   6.323.117 |
# |  PSV  |      1.818 |      1.668 |      2.716 |    167.213 |    347.156 |   5.810.839 |
# |n-2DSLL|      3.719 |      3.724 |     28.004 |    300.123 |    405.149 |     887.674 |
# |  2DS  |        335 |        228 |      2.316 |     19.804 |    253.815 |     582.494 |
# | n-3DS |      2.002 |      2.089 |     10.262 |    162.032 |    879.853 |   5.830.058 |
# +-------+------------+------------+------------+------------+------------+-------------+
#
# Media Create / Famitsu database
# version 1.0.1 (2016 update) <-download it here
#
# Previous Threads
# 2017 | 2018
#
# Media Create Sales: Week 45, 2018 (Nov 05 - Nov 11)

# %% [markdown]
# I want to obtain the Famitsu Sales, as the Media Create no longer share the data. So I need to identify where the Famitsu numbers begin and divide the rows.

# %%
def obtain_top30_text(post_text):
    tab_top=post_text.split("Famitsu Sales: Week")[1]
    tab_top=tab_top.replace(" # ","").split("\n")
    return tab_top[2:32]

clean_tab=obtain_top30_text(tab_top30)
clean_tab
# Out:
# ["01./00.  [NSW] Pokemon: Let's Go, Pikachu! / Let's Go, Eevee!<RPG> (Pokemon Co.) {2018.11.16} (¥5.980) - 664.198 / NEW <40-60%> ",
#  '02./00.  [PS4] Fallout 76<RPG> (Bethesda Softworks) {2018.11.15} (¥7.980) - 60.222 / NEW <60-80%> ',
#  '03./02. [NSW] Super Mario Party <ETC> (Nintendo) {2018.10.05} (¥5.980) - 17.486 / 326.510 <80-100%> (-15%)',
#  '04./03. [PS4] Call of Duty: Black Ops IIII <ACT> (Sony Interactive Entertainment) {2018.10.12} (¥7.900) - 13.868 / 442.995 <80-100%> (-32%)',
#  "05./01. [3DS] Luigi's Mansion <ACT> (Nintendo) {2018.11.08} (¥4.980) - 10.716 / 40.121 <40-60%> (-64%)",
#  '06./00.  [PS4] Hitman 2 <ADV> (Warner Entertainment Japan) {2018.11.15} (¥7.800) - 10.688 / NEW <20-40%> ',
#  '07./05. [NSW] Mario Kart 8 Deluxe <RCE> (Nintendo) {2017.04.28} (¥5.980) - 9.948 / 1.849.467 <80-100%> (+14%)',
#  '08./04. [PS4] Red Dead Redemption II<ACT> (Take-Two Interactive Japan) {2018.10.26} (¥8.800) - 7.642 / 189.465 <80-100%> (-48%)',
#  '09./06. [NSW] Minecraft <ADV> (Microsoft Game Studios) {2018.06.21} (¥3.600) - 7.504 / 366.272 <80-100%> (-2%)',
#  '10./07. [NSW] Splatoon 2<ACT> (Nintendo) {2017.07.21} (¥5.980) - 7.482 / 2.736.533 <80-100%> (+11%)',
#  '11./08. [NSW] The Legend of Zelda: Breath of the Wild<ADV> (Nintendo) {2017.03.03} (¥6.980) - 5.463 / 1.121.636 <80-100%> (+12%)',
#  '12./00.  [PS4] Yuuna and the Haunted Hot Springs: Steam Dungeon<RPG> (FuRyu) {2018.11.15} (¥7.980) - 5.325 / NEW <40-60%> ',
#  '13./09. [3DS] Pokemon Ultra Sun / Ultra Moon<RPG> (Pokemon Co.) {2017.11.17} (¥4.980) - 4.049 / 2.395.774 <80-100%> (+1%)',
#  '14./10. [NSW] Super Mario Odyssey<ACT> (Nintendo) {2017.10.27} (¥5.980) - 3.630 / 1.836.141 <80-100%> (-6%)',
#  '15./00.  [PSV] Shiro to Kuro no Alice: Twilight Line<ADV> (Idea Factory) {2018.11.15} (¥6.300) - 3.068 / NEW <40-60%> ',
#  '16./00.  [NSW] RPG Maker MV Trinity <ETC> (Kadokawa Games) {2018.11.15} (¥7.800) - 3.015 / NEW <20-40%> ',
#  "17./11. [PS4] Marvel's Spider-Man<ADV> (Sony Interactive Entertainment) {2018.09.07} (¥6.900) - 2.849 / 294.847 <80-100%> (-13%)",
#  '18./00.  [PS4] RPG Maker MV Trinity <ETC> (Kadokawa Games) {2018.11.15} (¥7.800) - 2.243 / NEW <20-40%> ',
#  "19./12. [NSW] Taiko no Tatsujin: Drum 'n' Fun! <ACT> (Bandai Namco Games) {2018.07.19} (¥6.100) - 2.188 / 224.930 <80-100%> (-5%)",
#  '20./13. [NSW] Kirby Star Allies <ACT> (Nintendo) {2018.03.16} (¥5.980) - 2.049 / 619.949 <80-100%> (-4%)',
#  '21./17. [PS4] Winning Eleven 2019 <SPT> (Konami) {2018.08.30} (¥7.600) - 1.841 / 137.378 <80-100%> (+3%)',
#  '22./16. [PS4] Kingdom Hearts HD I.5 + II.5 ReMIX <Kingdom Hearts HD I.5 ReMIX <Kingdom Hearts \\ Kingdom Hearts Re:Chain of Memories> \\ Kingdom Hearts HD II.5 ReMIX <Kingdom Hearts II \\ Kingdom Hearts II: Final Mix+ \\ Kingdom Hearts: Birth by Sleep>> <RPG> (Square Enix) {2017.03.09} (¥6.800) - 1.728 / 215.144 <80-100%> (-12%)',
#  '23./23. [NSW] Mario Tennis Aces <SPT> (Nintendo) {2018.06.22} (¥5.980) - 1.649 / 351.946 <80-100%> (+9%)',
#  '24./22. [NSW] FIFA 19<SPT> (Electronic Arts) {2018.09.28} (¥5.800) - 1.524 / 36.375 <60-80%> (-6%)',
#  '25./20. [PS4] FIFA 19<SPT> (Electronic Arts) {2018.09.28} (¥7.800) - 1.385 / 93.924 <80-100%> (-19%)',
#  '26./25. [NSW] Dragon Ball FighterZ <FTG> (Bandai Namco Games) {2018.09.27} (¥6.800) - 1.254 / 44.146 <60-80%> (-13%)',
#  '27./27. [3DS] Animal Crossing: New Leaf - Welcome amiibo<ETC> (Nintendo) {2016.11.23} (¥2.700) - 1.239 / 407.238 <80-100%> (-3%)',
#  '28./19. [PS4] Tetris Effect <PZL> (Sony Interactive Entertainment) {2018.11.09} (¥4.167) - 1.238 / 3.016 <20-40%> (-30%)',
#  "29./14. [PS4] Assassin's Creed: Odyssey<RPG> (Ubisoft) {2018.10.05} (¥8.400) - 1.237 / 83.996 <80-100%> (-39%)",
#  '30./21. [NSW] Cats Together <ETC> (Bandai Namco Games) {2018.11.01} (¥5.700) - 1.202 / 5.979 <20-40%> (-26%)']

# %% [markdown]
# Now I need to create the most important function, the one that takes a row of the table in string form as an input and returns a list of formated data. I need to identify for each datapoint a regular rexpression that allows me to collect the desired information.
#
# The structure is different if it is a new release or not. Take a look for example *Fallout 76* and *Super Mario Party*.

# %%
def mine_sw_info(temp):
    row = []
    # Postition and previous week position
    row.append(int(re.findall(r"[0-9].",temp)[0]))
    row.append(int(re.findall(r"[0-9].",temp)[1]))
    # Find all things between [ ] and obtain the first one to get the system
    row.append(re.findall(r"\[(.*?)\]",temp)[0])
    # Find all things between < > and obtain the penultimate one to get the genre
    row.append(re.findall(r"\<(.*?)\>",temp)[-2])
    # Find all things between { } and obtain the last one to get the day of release
    row.append(re.findall(r"\{(.*?)\}",temp)[-1])



    if re.findall(r"\((.*?)\)",temp)[-1].find("%") >= 0: # Not a new release
        # Company
        row.append(re.findall(r"\((.*?)\)",temp)[-3])
        # Price
        row.append(  int(re.findall(r"\((.*?)\)",temp)[-2].replace(".","").replace("¥","")))
        # Units this week
        row.append(  int(re.findall(r"\)\ \-(.*?)\/",temp)[-1].replace(".","")))
        # Total units
        row.append(  int(re.findall(r"\/(.*?)\<",temp)[-1].replace(".","")))
        # Percentage of sales
        row.append(re.findall(r"\<(.*?)\>",temp)[-1])
        # Change with respect to the last week in percentage
        row.append(  int(re.findall(r"\((.*?)\)",temp)[-1].replace("%","").replace(" ","")))
        # Add a boolean to indicate this is not a new release
        row.append(  False )
    else:
        # Company
        row.append(re.findall(r"\((.*?)\)",temp)[-2])
        # Price
        row.append(int(re.findall(r"\((.*?)\)",temp)[-1].replace(".","").replace("¥","")))
        # Units this week
        row.append(int(re.findall(r"\)\ \-(.*?)\/",temp)[-1].replace(".","")))
        # Total Units = Units this week
        row.append(int(re.findall(r"\)\ \-(.*?)\/",temp)[-1].replace(".","")))
        # Percentage of sales
        row.append(re.findall(r"\<(.*?)\>",temp)[-1])
        # Change with respect to the last week in percentage, so put 0 to indicate new
        row.append(0)
        # Add a boolean to indicate this is not a new release
        row.append(  True )
    
    # Lastly, the name of the game
    name=temp.split(f"[{row[2]}]")[-1].split(f"<{row[3]}>")[0]
    row.append(name.lstrip().rstrip())
    return row

# %% [markdown]
# With the previous function, now I can iterate through all the rows in the top 30 video game sales. I need to include a header to keep track of what is each column and to convert. Finally I convert it to a Pandas DataFrame and include the year, the number of week and the days range in the week.

# %%
def create_top30_list(table_in,year,week,days,date):
    # need to create the header and append the rows in the top 30 game list
    header = ["Position", "Position Last Week","System","Genre","Launch Date","Company","Price","Sales (this week)",
              "LTD Sales","Range Sales","Change from last week","Launch this week","Game Title"]
    table_out=[header]
    # For each row in the top 30 game list, it appends the formated info in the list
    for row in table_in:
        table_out.append(mine_sw_info(row))
    
    # Converting the list to a Pandas DataFrame
    df = pd.DataFrame(table_out[1:],columns=table_out[0])
    # Adds in this dataframe a column with the year, the week number,
    # and the range of days in the week
    df["Year"]=year
    df["Week"]=week
    df["Days"]=days  
    df["Date"]=date
    return df

# %% [markdown]
# Now I'm going to check that everything works as it should...

# %%
df2=create_top30_list(clean_tab,2018,46,"nov 12 / nov 18","12/11/2018")
df2.head()
# Out:
#    Position  Position Last Week System Genre Launch Date  \
# 0         1                   0    NSW   RPG  2018.11.16
# 1         2                   0    PS4   RPG  2018.11.15
# 2         3                   2    NSW   ETC  2018.10.05
# 3         4                   3    PS4   ACT  2018.10.12
# 4         5                   1    3DS   ACT  2018.11.08
#
#                           Company  Price  Sales (this week)  LTD Sales  \
# 0                     Pokemon Co.   5980             664198     664198
# 1              Bethesda Softworks   7980              60222      60222
# 2                        Nintendo   5980              17486     326510
# 3  Sony Interactive Entertainment   7900              13868     442995
# 4                        Nintendo   4980              10716      40121
#
#   Range Sales  Change from last week  Launch this week  \
# 0      40-60%                      0              True
# 1      60-80%                      0              True
# 2     80-100%                    -15             False
# 3     80-100%                    -32             False
# 4      40-60%                    -64             False
#
#                                        Game Title  Year  Week  \
# 0  Pokemon: Let's Go, Pikachu! / Let's Go, Eevee!  2018    46
# 1                                      Fallout 76  2018    46
# 2                               Super Mario Party  2018    46
# 3                    Call of Duty: Black Ops IIII  2018    46
# 4                                 Luigi's Mansion  2018    46
#
#               Days        Date
# 0  nov 12 / nov 18  12/11/2018
# 1  nov 12 / nov 18  12/11/2018
# 2  nov 12 / nov 18  12/11/2018
# 3  nov 12 / nov 18  12/11/2018
# 4  nov 12 / nov 18  12/11/2018

# %% [markdown]
# And it does!
#
#
# ![it works](https://wb4son.com/wpblog/wp-content/uploads/2016/09/Alive.gif)

# %% [markdown]
# ### Getting all the data available to create the dataset
#
# The next step is to use this function *urbi et orbi*. I mean, to all post with this info in the ResetEra forum.
#
# There is a post with all links to each weekly post, so let's web scrap it... In the block of code below I am going to retrieve all links in the post and store them in `links`.

# %%
url="https://www.resetera.com/threads/media-create-sales-archive-thread.4115/"
ustitles = requests.get(url)
soup = BeautifulSoup(ustitles.text)
links=soup.findAll("a", {"class": "link link--internal"})

# %% [markdown]
# Ok, so lets build the final loop to obtain the dataset.

# %%
# List with the URL of each post
links_clean=[]
# List with the year, week number and range of days in the week
links_data=[]
# Empty dataframe where I will store the final dataset
df_sw = pd.DataFrame()
# A list with the links where something failed and the script didn't work
error=[]
# Dictionary with the numerical values of the month
months={"jan":"1","feb":"2","mar":"3","apr":"4","may":"5","jun":"6","jul":"7","aug":"8","sep":"9","oct":"10","nov":"11","dec":"12"}

# Looping to mine the weekly data
for el in links[::-1]:
    # There are links where it is stored the yearly info instead of the weekly ones. 
    # We do not want these ones, so we use the following if statement to discard those.
    # They have "new-used" in the title and in their URL, so it is easy.
    if ( el.get('href').find("new-used") < 0):
        # Store the URL in a file
        links_clean.append(el.get('href'))
        time.sleep(1) # Just in case, to not to get an error due to do a lot of requests
        try:
            # Get the text table
            text_tab=obtain_top30_text(obtain_post(links_clean[-1]))
            # Obtain the year, week number and range of days in the week from the URL
            # and store them in links_data
            temp=links_clean[-1].split(".")[2].split("-")[-6:]
            temp_data=[int(temp[1]),int(temp[0]),temp[2]+" "+temp[3]+" / "+temp[4]+" "+temp[5],
                              temp[3]+"/"+months[temp[2]]+"/"+temp[1]]
            links_data.append(temp_data)
            # Append the weekly info dataframe in the final dataset
            df_sw=df_sw.append(create_top30_list(text_tab,temp_data[0],temp_data[1],temp_data[2],temp_data[3]))
        except:  # If there was an erron, store the URL in the error list
            error.append(links_clean[-1])

# Reseting the final dataframe index
df_sw=df_sw.reset_index()
# Convert Date column to datetime
df_sw["Date"]=pd.to_datetime(df_sw["Date"], infer_datetime_format=True)

# %%
df_sw.head()
# Out:
#    index  Position  Position Last Week System Genre Launch Date   Company  \
# 0      0         1                   1    NSW   TBL  2020.11.19    Konami
# 1      1         2                   2    NSW   ETC  2020.03.20  Nintendo
# 2      2         3                   3    NSW   HOB  2019.10.18  Nintendo
# 3      3         4                   4    NSW   RCE  2017.04.28  Nintendo
# 4      4         5                   5    NSW   FTG  2018.12.07  Nintendo
#
#    Price  Sales (this week)  LTD Sales Range Sales  Change from last week  \
# 0   6300             107064    1617601     80-100%                     23
# 1   5980              36009    6553618     80-100%                    -20
# 2   7980              35397    2237398     80-100%                    -20
# 3   5980              26636    3601699     80-100%                    -22
# 4   7200              17099    4109327     80-100%                    -29
#
#    Launch this week                                         Game Title  Year  \
# 0             False  Momotaro Dentetsu: Showa, Heisei, Reiwa mo Tei...  2021
# 1             False                      Animal Crossing: New Horizons  2021
# 2             False                                 Ring Fit Adventure  2021
# 3             False                                Mario Kart 8 Deluxe  2021
# 4             False                         Super Smash Bros. Ultimate  2021
#
#    Week             Days       Date
# 0     2  jan 11 / jan 17 2021-11-01
# 1     2  jan 11 / jan 17 2021-11-01
# 2     2  jan 11 / jan 17 2021-11-01
# 3     2  jan 11 / jan 17 2021-11-01
# 4     2  jan 11 / jan 17 2021-11-01

# %%
df_sw.tail()
# Out:
#       index  Position  Position Last Week System Genre Launch Date  \
# 5035     25        26                  23    NSW   FTG  2017.09.07
# 5036     26        27                  17    PS4   RPG  2017.09.28
# 5037     27        28                  25    PS4   RPG  2017.07.29
# 5038     28        29                  28    PS4   ACT  2015.10.08
# 5039     29        30                  13    PS4   SLG  2017.10.14
#
#                              Company  Price  Sales (this week)  LTD Sales  \
# 5035              Bandai Namco Games   6800               2011      45219
# 5036                    Nihon Falcom   7800               1966     120050
# 5037                     Square Enix   8980               1927    1321426
# 5038      Take-Two Interactive Japan   4990               1907     304725
# 5039  Sony Interactive Entertainment   4900               1906       6604
#
#      Range Sales  Change from last week  Launch this week  \
# 5035     80-100%                    -33             False
# 5036     80-100%                    -55             False
# 5037     80-100%                    -22             False
# 5038     80-100%                     -8             False
# 5039     80-100%                    -59             False
#
#                                           Game Title  Year  Week  \
# 5035    Dragon Ball: Xenoverse 2 for Nintendo Switch  2017    42
# 5036  The Legend of Heroes: Trails of Cold Steel III  2017    42
# 5037       Dragon Quest XI: Echoes of an Elusive Age  2017    42
# 5038          Grand Theft Auto V [New Price Edition]  2017    42
# 5039          No Heroes Allowed! VR |PlayStation VR|  2017    42
#
#                  Days       Date
# 5035  oct 16 / oct 22 2017-10-16
# 5036  oct 16 / oct 22 2017-10-16
# 5037  oct 16 / oct 22 2017-10-16
# 5038  oct 16 / oct 22 2017-10-16
# 5039  oct 16 / oct 22 2017-10-16

# %% [markdown]
# Only 2 of them returns an error, so we've got a very complete dataset using web scraping.

# %%
error
# Out:
# ['https://www.resetera.com/threads/media-create-sales-week-32-2019-aug-05-aug-11.134991/',
#  'https://www.resetera.com/threads/media-create-sales-week-19-2019-may-06-may-12.117093/']

# %% [markdown]
# And now I leave it to you to have fun with the dataset!

# %% [markdown]
# ### A bit of fun with the database
#
# Now I will play a little bit with the dataset. For example, let's see the popularity of genres by checking the sum of the titles in the top 30. It seems that the most popular ones are action, RPG and adventure games.

# %%
df_sw["Genre"].value_counts()
# Out:
# ACT    1534
# RPG     881
# ADV     812
# SPT     403
# ETC     357
# FTG     303
# RCE     219
# SLG     205
# HOB     148
# TBL      72
# EDU      49
# PZL      40
# STG      17
# Name: Genre, dtype: int64

# %% [markdown]
# Now let's check the number of times a company made a game to be in the top 30. Nintendo seems to be dominating the top 30 charts in Japan, followed by Bandai Namco and Square Enix.

# %%
df_sw["Company"].value_counts()[:10]
# Out:
# Nintendo                          1896
# Bandai Namco Games                 504
# Square Enix                        316
# Pokemon Co.                        287
# Sony Interactive Entertainment     192
# Capcom                             179
# Konami                             155
# Sega                               148
# Microsoft Game Studios             144
# Koei Tecmo                         141
# Name: Company, dtype: int64

# %% [markdown]
# And now the times a company made a game to be the best selling video game in the week. As before the most succesful company is Nintendo. The second and the third places belongs to Sony and the Pokemon Company.

# %%
df_sw[df_sw["Position"] == 1]["Company"].value_counts()[:10]
# Out:
# Nintendo                          66
# Pokemon Co.                       16
# Sony Interactive Entertainment    16
# Konami                            13
# Bandai Namco Games                 9
# Capcom                             8
# Square Enix                        7
# Sega                               5
# Koei Tecmo                         4
# Atlus                              4
# Name: Company, dtype: int64

# %% [markdown]
# Checking the number of times a title made in the top 30, we see that there are 3 titles that, within the time range of the dataset, they appear in all top 30 weekly charts.

# %%
df_sw["Game Title"].value_counts()[:10]
# Out:
# Mario Kart 8 Deluxe                                                             168
# The Legend of Zelda: Breath of the Wild                                         168
# Splatoon 2                                                                      168
# Super Mario Odyssey                                                             138
# Minecraft                                                                       133
# Super Mario Party                                                               118
# Super Smash Bros. Ultimate                                                      109
# New Super Mario Bros. U Deluxe <New Super Mario Bros. U \ New Super Luigi U>    103
# Taiko no Tatsujin: Drum 'n' Fun!                                                101
# Pokemon Ultra Sun / Ultra Moon                                                   82
# Name: Game Title, dtype: int64

# %% [markdown]
# Now let's see the number of times a game made in the top of the list. Animal Crossing is the winner!

# %%
df_sw[df_sw["Position"] == 1]["Game Title"].value_counts()[:10]
# Out:
# Animal Crossing: New Horizons                         20
# Pokemon Sword / Shield                                10
# Momotaro Dentetsu: Showa, Heisei, Reiwa mo Teiban!     9
# Super Smash Bros. Ultimate                             7
# Super Mario Maker 2                                    6
# Monster Hunter: World                                  5
# Splatoon 2                                             4
# Ring Fit Adventure                                     4
# Kirby Star Allies                                      3
# Marvel's Spider-Man                                    3
# Name: Game Title, dtype: int64

# %% [markdown]
# Finally, I will put a list with the 10 most sucessful launches within the range of time of the dataset:

# %%
df_sw[df_sw["Launch this week"]].sort_values(by=['Sales (this week)'],ascending=False).head(10)
# Out:
#       index  Position  Position Last Week System Genre Launch Date  \
# 1290      0         1                   0    NSW   ETC  2020.03.20
# 1830      0         1                   0    NSW   RPG  2019.11.15
# 4590      0         1                   0    PS4   ACT  2018.01.26
# 3240      0         1                   0    NSW   FTG  2018.12.07
# 4890      0         1                   0    3DS   RPG  2017.11.17
# 1200      0         1                   0    PS4   RPG  2020.04.10
# 3330      0         1                   0    NSW   RPG  2018.11.16
# 3030      0         1                   0    PS4   RPG  2019.01.25
# 4980      0         1                   0    NSW   ACT  2017.10.27
# 240       0         1                   0    NSW   TBL  2020.11.19
#
#           Company  Price  Sales (this week)  LTD Sales Range Sales  \
# 1290     Nintendo   5980            1880626    1880626     80-100%
# 1830  Pokemon Co.   5980            1364544    1364544      60-80%
# 4590       Capcom   8980            1350412    1350412     80-100%
# 3240     Nintendo   7200            1238358    1238358      60-80%
# 4890  Pokemon Co.   4980            1199814    1199814      60-80%
# 1200  Square Enix   8980             702853     702853     80-100%
# 3330  Pokemon Co.   5980             664198     664198      40-60%
# 3030  Square Enix   8800             640406     640406      60-80%
# 4980     Nintendo   5980             511625     511625     80-100%
# 240        Konami   6300             345697     345697      60-80%
#
#       Change from last week  Launch this week  \
# 1290                      0              True
# 1830                      0              True
# 4590                      0              True
# 3240                      0              True
# 4890                      0              True
# 1200                      0              True
# 3330                      0              True
# 3030                      0              True
# 4980                      0              True
# 240                       0              True
#
#                                              Game Title  Year  Week  \
# 1290                      Animal Crossing: New Horizons  2020    12
# 1830                             Pokemon Sword / Shield  2019    46
# 4590                              Monster Hunter: World  2018     4
# 3240                         Super Smash Bros. Ultimate  2018    49
# 4890                     Pokemon Ultra Sun / Ultra Moon  2017    46
# 1200                           Final Fantasy VII Remake  2020    15
# 3330     Pokemon: Let's Go, Pikachu! / Let's Go, Eevee!  2018    46
# 3030                                 Kingdom Hearts III  2019     4
# 4980                                Super Mario Odyssey  2017    43
# 240   Momotaro Dentetsu: Showa, Heisei, Reiwa mo Tei...  2020    47
#
#                  Days       Date
# 1290  mar 16 / mar 22 2020-03-16
# 1830  nov 11 / nov 17 2019-11-11
# 4590  jan 22 / jan 28 2018-01-22
# 3240  dec 03 / dec 09 2018-03-12
# 4890  nov 13 / nov 19 2017-11-13
# 1200  apr 06 / apr 12 2020-06-04
# 3330  nov 12 / nov 18 2018-12-11
# 3030  jan 21 / jan 27 2019-01-21
# 4980  oct 23 / oct 29 2017-10-23
# 240   nov 16 / nov 22 2020-11-16

# %% [markdown]
# And now... it's your turn to play with the dataset!
